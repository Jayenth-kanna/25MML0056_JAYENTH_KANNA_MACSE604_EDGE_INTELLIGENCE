# %%
import os
from PIL import Image
import numpy as np
from collections import Counter
folder = "samples"

for file in os.listdir(folder):
    img = Image.open(file)  
    arr = np.array(img)
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[4], line 8
#       5 folder = "samples"
#       7 for file in os.listdir(folder):
# ----> 8     img = Image.open(file)
#       9     arr = np.array(img)
#
# File /opt/anaconda3/lib/python3.13/site-packages/PIL/Image.py:3465, in open(fp, mode, formats)
#    3462     filename = os.fspath(fp)
#    3464 if filename:
# -> 3465     fp = builtins.open(filename, "rb")
#    3466     exclusive_fp = True
#    3467 else:
#
# FileNotFoundError: [Errno 2] No such file or directory: 'p5g5m.png'

# %%
import os
from PIL import Image
import numpy as np
from collections import Counter
folder = "samples"

for file in os.listdir(folder):
    path = os.path.join(folder, file)
    img = Image.open(path)   
    arr = np.array(img)
    for file in os.listdir(folder):
    if file.endswith(".jpg"):   # only lowercase .jpg
        path = os.path.join(folder, file)
        img = Image.open(path)
# Out:
#   Cell In[6], line 12
#     if file.endswith(".jpg"):   # only lowercase .jpg
#     ^
# IndentationError: expected an indented block after 'for' statement on line 11

# %%
import os
from PIL import Image
import numpy as np
from collections import Counter
folder = "samples"
for file in os.listdir(folder):
    if file.endswith(".jpg"):
        path = os.path.join(folder, file)
        img = Image.open(path)
        arr = np.array(img)
        shapes.append(arr.shape)
shape_count = Counter(shapes)
print("Total images:", len(shapes))
print("\nImage shapes and counts:")
for shape, count in shape_count.items():
    print(f"{shape}: {count}")
summary = []
for shape, count in shape_count.items():
    summary.append(f"{count} images have shape {shape}")

print("\nSummary:")
print(", ".join(summary))
# Out:
# Total images: 1100
#
# Image shapes and counts:
# (50, 200, 4): 1040
# (50, 200, 3): 60
#
# Summary:
# 1040 images have shape (50, 200, 4), 60 images have shape (50, 200, 3)

# %%
import os
from PIL import Image
import numpy as np
from collections import Counter

folder = "samples"   # change to your folder

shapes = []

for file in os.listdir(folder):
    if file.lower().endswith((".jpg", ".png", ".jpeg")):
        path = os.path.join(folder, file)
        img = Image.open(path)
        arr = np.array(img)
        shapes.append(arr.shape)

# frequency of each shape
shape_count = Counter(shapes)

print("Total images:", len(shapes))
print("\nImage shapes and counts:")
for shape, count in shape_count.items():
    print(f"{shape}: {count}")

# tiny NLP-style text summary (simple, not complicated)
summary = []
for shape, count in shape_count.items():
    summary.append(f"{count} images have shape {shape}")

print("\nSummary:")
print(", ".join(summary))
# Out:
# Total images: 1070
#
# Image shapes and counts:
# (50, 200, 4): 1040
# (50, 200, 3): 30
#
# Summary:
# 1040 images have shape (50, 200, 4), 30 images have shape (50, 200, 3)
